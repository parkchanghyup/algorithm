# %%
def solution(skill, skill_trees):
    answer = 0
    
    for skill_tree in skill_trees:
        check = []
        for char in skill_tree:
            if char not in check and char in skill:
                check.append(char)
        
        
        
        length = min(len(check),len(skill))
        
        answer +=1
        for i in range(length):
            if check[i] != skill[i]:
                answer -=1
                break
            
                
            
    return answer
solution("CBD",["BACDE", "CBADF", "AECB", "BDA"])
# Out:
# ['B', 'C', 'D']
# ['C', 'B', 'D']
# ['C', 'B']
# ['B', 'D']
# 2

# %%
#점프와 순간 이동
# 한번에 K 칸 이동 하거나 , 현재까지온거리 x2 에 해당하는 위치로 순간이동
# k칸 이동할떄는 배털 k만큼 사용 순간이동은 배터리 소모 x 
# n칸 이동을 위해 사용해야하는 건전지 량 최소 출력


def solution(n):
    cnt = 0
    while n> 0:
        
        if n%2 ==0:
            n//=2
        else:
            n//=2
            cnt+=1
        

    return cnt
solution(5)
# Out:
# 2

# %%
def solution(n, words):
    answer = []
    past = [words[0]]
    cnt = 1 
    pos = True
    for idx in range(1,len(words)):
        
        word = words[idx]
        if word in past or word[0] != words[idx-1][-1]:
            pos = False
            break
            
        past.append(word)
    
    idx +=1    
    
    if idx == len(words) and pos == True:
        return [0,0]
    
    a,b = (divmod(idx,n))
    if b == 0 :
        return [n,a]
    
    return [b,a+1]
    
    
solution(	5, ["hello", "observe", "effect", "take", "either", "recognize", "encourage", "ensure", "establish", "hang", "gather", "refer", "reference", "estimate", "executive"])
# Out:
# ['hello', 'observe']
# ['hello', 'observe', 'effect']
# ['hello', 'observe', 'effect', 'take']
# ['hello', 'observe', 'effect', 'take', 'either']
# ['hello', 'observe', 'effect', 'take', 'either', 'recognize']
# ['hello', 'observe', 'effect', 'take', 'either', 'recognize', 'encourage']
# ['hello', 'observe', 'effect', 'take', 'either', 'recognize', 'encourage', 'ensure']
# ['hello', 'observe', 'effect', 'take', 'either', 'recognize', 'encourage', 'ensure', 'establish']
# ['hello', 'observe', 'effect', 'take', 'either', 'recognize', 'encourage', 'ensure', 'establish', 'hang']
# ['hello', 'observe', 'effect', 'take', 'either', 'recognize', 'encourage', 'ensure', 'establish', 'hang', 'gather']
# ['hello', 'observe', 'effect', 'take', 'either', 'recognize', 'encourage', 'ensure', 'establish', 'hang', 'gather', 'refer']
# ['hello', 'observe', 'effect', 'take', 'either', 'recognize', 'encourage', 'ensure', 'establish', 'hang', 'gather', 'refer', 'reference']
# ...

# %%
def solution(dirs):
    answer = 0

    x, y = 0, 0

    # U D R L
    dx = [0, 0, 1, -1]
    dy = [-1, 1, 0, 0]

    dir = 0
    root = []
    for char in dirs:

        if char == 'U':
            dir = 0
        elif char == 'D':
            dir = 1
        elif char == 'R':
            dir = 2
        elif char == 'L':
            dir = 3
            
        

        nx = x + dx[dir]
        ny = y + dy[dir]
        
        if -6 < nx < 6 and -6 < ny < 6:
            candidate = sorted([(x, y), (nx, ny)])

            if candidate not in root:
                root.append(candidate)
            x = nx
            y = ny

    return len(root)


solution('LULLLLLLU')
# Out:
# 7

# %%
# 배달


import heapq
import collections

def solution(N, road, K):
    answer = 0
    
    graph = collections.defaultdict(list)
    
    # 그래프 생성
    for u,v,w in road:
        graph[u].append((v,w))
        graph[v].append((u,w))
        
    Q = [(0,1)]
    
    dist = collections.defaultdict(int)
    
    while Q:
        time,node = heapq.heappop(Q)
    
        if node not in dist :
            dist[node] = time            
            for v,w in graph[node]:
                heapq.heappush(Q,(w+time,v))
    
    result = 0
    
    for key in dist.keys():
        if dist[key] <=K:
            result +=1
            
    return result

solution(5, [[1, 2, 1], [2, 3, 3], [5, 2, 2], [1, 4, 2], [5, 3, 1], [5, 4, 2]], 3)
# Out:
# 4

# %%
# 기지국 설치
import math


def solution(N, stations, W):
    answer = 0

    install_length = []
    left = 0
    for idx, s in enumerate(stations):
        install_length.append((s-W) - left-1)
        left = s+W
        
        # 마지막이면 오른쪽도
        if idx == len(stations) - 1:
            install_length.append(N - (s+W))
    print(install_length)
    
    
    install_length = [x for x in install_length if x >= 0]
    
    W = W*2 + 1
    result = 0

    for install in install_length:
        Size = math.ceil(install / W)
        answer += Size
    return answer


solution(11, [4, 11], 1)
# Out:
# [2, 4, -1]
# 3

# %%
def binary_search(target, numbers):
    lo, hi = 0, len(numbers)-1
    result = -1
    while lo <= hi:
        mid = (lo+hi)//2

        if numbers[mid] <= target:
            lo = mid + 1
        else:
            result = mid
            hi = mid - 1

    return result


def solution(A, B):
    B.sort()
    answer = 0
    for num in A:

        idx = binary_search(num, B)

        if idx == -1:
            continue

        else:
            B.pop(idx)
            answer += 1

    return answer
# Out:
# 0

# %%
from collections import deque


def solution(land, height):

    def bfs(x, y):

        Q = deque()
        Q.append((x,y))

        while Q:

            x, y = Q.popleft()

            for i in range(4):
                nx = x+dx[i]
                ny = y + dy[i]

                if nx > -1 and ny > -1 and nx < len(land) and ny < len(land):
                    if visited[nx][ny] == 0 and abs(land[nx][ny] - land[x][y]) <= height:
                        Q.append((nx, ny))
                        visited[nx][ny] = 1

    answer = 0
    visited = [[0] * len(land) for _ in range(len(land))]

    dx = [1, 0, -1, 0]
    dy = [0, 1, 0, -1]
    x, y = 0, 0
    next_start = [0, 0, int(1e9)]
    cost = 0
    
    while True:
        bfs(x, y)

        for i in range(len(land)):
            for j in range(len(land)):
                if visited[i][j] == 0:

                    for div in range(4):
                        nx = i + dx[div]
                        ny = j + dy[div]
                        if nx > -1 and ny > -1 and nx < len(land) and ny < len(land):
                            if visited[nx][ny] == 1:
                                cost = land[i][j] - land[nx][ny]
                        if next_start[2] > cost:
                            next_start = [i, j, cost]
        x, y, cost = next_start
        check = 0

        answer += cost

        for i in range(len(visited)):
            check += sum(visited[i])
        if check == len(visited)*len(visited):
            break
        print(x,y,check)
    return answer


solution([[1, 4, 8, 10], [5, 5, 5, 5], [10, 10, 10, 10], [10, 10, 10, 20]], 3)
# Out:
# 2 0 8
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# 2 0 15
# ...
